# %%
from covidtracker import CovidTracker
import numpy as np
import pandas as pd

# %%
cd = CovidTracker()

# %%
cd.load_counties()

# %%
dt=cd.getmostrecentdate()
dt
# Out:
# '2020-05-25'

# %%
dperc = cd.getdeathspercase('2020-05-25')
dperc = dperc.loc[dperc['cases']>2000]
dperc.sort_values('deaths per case', ascending=False)
# Out:
#               date          county           state   cases  deaths  \
# 174061  2020-05-25        Hartford     Connecticut    9841    1187
# 175004  2020-05-25          Macomb        Michigan    6516     778
# 175037  2020-05-25           Wayne        Michigan   19816    2364
# 175017  2020-05-25         Oakland        Michigan    8226     955
# 175737  2020-05-25           Lucas            Ohio    2126     229
# 175898  2020-05-25         Chester    Pennsylvania    2428     251
# 175517  2020-05-25   New York City        New York  203569   20740
# 174953  2020-05-25         Norfolk   Massachusetts    7844     784
# 175919  2020-05-25       Lancaster    Pennsylvania    2896     281
# 175929  2020-05-25      Montgomery    Pennsylvania    6576     633
# 175448  2020-05-25          Morris      New Jersey    6259     593
# 174949  2020-05-25         Hampden   Massachusetts    5755     543
# 175892  2020-05-25           Bucks    Pennsylvania    4894     461
# 175441  2020-05-25           Essex      New Jersey   17202    1595
# 175452  2020-05-25        Somerset      New Jersey    4480     399
# 175502  2020-05-25            Erie        New York    5700     490
# 175436  2020-05-25          Bergen      New Jersey   17901    1525
# 175296  2020-05-25       St. Louis        Missouri    4544     387
# 173862  2020-05-25            Pima         Arizona    2046     173
# 175906  2020-05-25        Delaware    Pennsylvania    6234     524
# 174064  2020-05-25       New Haven     Connecticut   11017     922
# 175449  2020-05-25           Ocean      New Jersey    8430     690
# 174060  2020-05-25       Fairfield     Connecticut   15213    1221
# 175889  2020-05-25           Berks    Pennsylvania    3903     296
# 175064  2020-05-25        Hennepin       Minnesota    7168     539
# 174951  2020-05-25       Middlesex   Massachusetts   20539    1527
# 174845  2020-05-25           Caddo       Louisiana    2343     174
# 175514  2020-05-25          Monroe        New York    2734     200
# 174872  2020-05-25         Orleans       Louisiana    7005     500
# 175435  2020-05-25        Atlantic      New Jersey    2028     144
# ...            ...             ...             ...     ...     ...
# 174184  2020-05-25          DeKalb         Georgia    3305     104
# 174071  2020-05-25          Sussex        Delaware    4118     126
# 176351  2020-05-25          Travis           Texas    2933      85
# 176346  2020-05-25         Tarrant           Texas    4977     144
# 174608  2020-05-25            Polk            Iowa    3795     109
# 176587  2020-05-25          Yakima      Washington    3066      87
# 176163  2020-05-25           Bexar           Texas    2461      69
# 174384  2020-05-25            Kane        Illinois    5846     152
# 176487  2020-05-25         Loudoun        Virginia    2047      52
# 176214  2020-05-25         El Paso           Texas    2376      58
# 173971  2020-05-25          Orange      California    5469     131
# 176202  2020-05-25          Dallas           Texas    8998     211
# 175606  2020-05-25     Mecklenburg  North Carolina    3380      74
# 176132  2020-05-25          Shelby       Tennessee    4451      94
# 176244  2020-05-25          Harris           Texas   10921     220
# 174996  2020-05-25            Kent        Michigan    3385      68
# 176516  2020-05-25  Prince William        Virginia    4702      94
# 175034  2020-05-25         Unknown        Michigan    3438      68
# 174210  2020-05-25            Hall         Georgia    2327      41
# 175754  2020-05-25        Pickaway            Ohio    2043      35
# 173979  2020-05-25   San Francisco      California    2389      40
# 176392  2020-05-25       Salt Lake            Utah    4583      68
# 176645  2020-05-25           Brown       Wisconsin    2249      32
# 176038  2020-05-25       Minnehaha    South Dakota    3274      43
# 176072  2020-05-25        Davidson       Tennessee    4821      58
# 176321  2020-05-25          Potter           Texas    2238      26
# 174629  2020-05-25        Woodbury            Iowa    2635      24
# 175360  2020-05-25         Douglas        Nebraska    3200      29
# 175740  2020-05-25          Marion            Ohio    2619      21
# 174286  2020-05-25         Unknown         Georgia    2294       0
#
#         deaths per case
# 174061         0.120618
# 175004         0.119398
# 175037         0.119298
# 175017         0.116095
# 175737         0.107714
# 175898         0.103377
# 175517         0.101882
# 174953         0.099949
# 175919         0.097030
# 175929         0.096259
# 175448         0.094744
# 174949         0.094353
# 175892         0.094197
# 175441         0.092722
# 175452         0.089063
# 175502         0.085965
# 175436         0.085191
# 175296         0.085167
# 173862         0.084555
# 175906         0.084055
# 174064         0.083689
# 175449         0.081851
# 174060         0.080260
# 175889         0.075839
# 175064         0.075195
# 174951         0.074346
# 174845         0.074264
# 175514         0.073153
# 174872         0.071378
# 175435         0.071006
# ...                 ...
# 174184         0.031467
# 174071         0.030597
# 176351         0.028981
# 176346         0.028933
# 174608         0.028722
# 176587         0.028376
# 176163         0.028037
# 174384         0.026001
# 176487         0.025403
# 176214         0.024411
# 173971         0.023953
# 176202         0.023450
# 175606         0.021893
# 176132         0.021119
# 176244         0.020145
# 174996         0.020089
# 176516         0.019991
# 175034         0.019779
# 174210         0.017619
# 175754         0.017132
# 173979         0.016743
# 176392         0.014837
# 176645         0.014229
# 176038         0.013134
# 176072         0.012031
# 176321         0.011618
# 174629         0.009108
# 175360         0.009062
# 175740         0.008018
# 174286         0.000000
#
# [132 rows x 6 columns]

# %%
diff = cd.getperioddifference('2020-05-25', 1, stat='deaths').replace([np.inf], 0)

# %%
diff.dropna().sort_values(ascending=False)

# %%
import matplotlib.pyplot as plt
ckco.plot(x='date', y='cases')
plt.show()

# %%
fla = cd.getstateframe('Florida')

# %%
fla.loc['2020-05-25']-fla.loc['2020-05-18']

# %%
fla.loc['2020-05-18']-fla.loc['2020-05-11']

# %%
fla.loc['2020-05-11']-fla.loc['2020-05-04']

# %%
nyc = cd.getcountyframe('New York', 'New York City')
ckco = cd.getcountyframe('Illinois', 'Cook')

# %%
ckco = ckco.set_index('date')
nyc = nyc.set_index('date')

# %%
ckco_cases = ckco['cases'].rename('ck')
nyc_cases = nyc['cases'].rename('ny')
ckco_deaths = ckco['deaths'].rename('ck')
nyc_deaths = nyc['deaths'].rename('ny')

# %%
ck_vs_ny=pd.concat([ckco_deaths, nyc_deaths], axis=1, join='inner')

# %%
ck_vs_ny.plot()

# %%
franklin = cd.getcountyframe('Ohio', 'Franklin')

# %%
dperc = franklin['deaths']/franklin['cases']

# %%
locals()
